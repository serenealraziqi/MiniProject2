# %%
1+1
# Out:
# 2

# %%
import os
os.getcwd()
# Out:
# '/shared_folder/MP2/MiniProject2'

# %%
import os
os.path.exists(".env")
# Out:
# True

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # loads .env in current folder
DATABASE_URL = os.getenv("DATABASE_URL")
DATABASE_URL is not None
# Out:
# False

# %%
import os, urllib.parse
from sqlalchemy import create_engine, text
import pandas as pd

u = os.getenv("POSTGRES_USERNAME")
p = urllib.parse.quote_plus(os.getenv("POSTGRES_PASSWORD",""))
h = os.getenv("POSTGRES_SERVER")
d = os.getenv("POSTGRES_DATABASE")

DATABASE_URL = f"postgresql+psycopg2://{u}:{p}@{h}/{d}?sslmode=require"

engine = create_engine(DATABASE_URL, pool_pre_ping=True)
with engine.connect() as conn:
    pd.read_sql_query(text("SELECT current_database() as db, current_user as usr;"), conn)

# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect(DATABASE_URL, connect_timeout=10)
pd.read_sql_query("SELECT version();", conn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[6], line 4
#       1 import psycopg2
#       2 import pandas as pd
# ----> 4 conn = psycopg2.connect(DATABASE_URL, connect_timeout=10)
#       5 pd.read_sql_query("SELECT version();", conn)
#
# File /opt/venv/lib/python3.12/site-packages/psycopg2/__init__.py:121, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     118 if 'async_' in kwargs:
#     119     kwasync['async_'] = kwargs.pop('async_')
# --> 121 dsn = _ext.make_dsn(dsn, **kwargs)
#     122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# File /opt/venv/lib/python3.12/site-packages/psycopg2/extensions.py:159, in make_dsn(dsn, **kwargs)
#     156 kwargs = {k: v for (k, v) in kwargs.items() if v is not None}
#     158 if dsn is not None:
# --> 159     tmp = parse_dsn(dsn)
# ...

# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install sqlalchemy psycopg2-binary

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '2.0.44'

# %%
python -m pip install sqlalchemy psycopg2-binary
# Out:
#   Cell In[9], line 1
#     python -m pip install sqlalchemy psycopg2-binary
#               ^
# SyntaxError: invalid syntax

# %%
import sys
# !{sys.executable} -m pip install sqlalchemy psycopg2-binary

# %%
from dotenv import load_dotenv
import os, urllib.parse

load_dotenv()  # uses .env in current folder

u = os.getenv("POSTGRES_USERNAME")
p = urllib.parse.quote_plus(os.getenv("POSTGRES_PASSWORD",""))
h = os.getenv("POSTGRES_SERVER")
d = os.getenv("POSTGRES_DATABASE")

DATABASE_URL = f"postgresql+psycopg2://{u}:{p}@{h}/{d}?sslmode=require"

# %%
import pandas as pd
from sqlalchemy import create_engine, text

engine = create_engine(DATABASE_URL, pool_pre_ping=True)

with engine.connect() as conn:
    pd.read_sql_query(text("SELECT current_database() AS db, current_user AS usr, version() AS version;"), conn)

# %%
with engine.connect() as conn:
    pd.read_sql_query(text("""
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema='public'
    ORDER BY table_name;
    """), conn)

# %%
# !pip -q install psycopg2-binary python-dotenv

# %%
import os
os.environ["DATABASE_URL"] = "postgresql://mini_project_2_z393_user:iYc6jbY29wNNBHFN4GFzae2auKshl0X7@dpg-d4mbp86uk2gs738s5bg0-a.virginia-postgres.render.com/mini_project_2_z393"

# %%
import os
import psycopg2
import pandas as pd

DATABASE_URL = os.environ["DATABASE_URL"]

conn = psycopg2.connect(DATABASE_URL, sslmode="require")
pd.read_sql_query("SELECT version();", conn)
# Out:
# /tmp/ipykernel_492/3519192596.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT version();", conn)
#                                              version
# 0  PostgreSQL 18.1 (Debian 18.1-1.pgdg12+2) on x8...

# %%
import os
from urllib.parse import urlparse

u = urlparse(os.environ["DATABASE_URL"])
print("host =", u.hostname)
print("db   =", u.path)
print("user =", u.username)
# Out:
# host = dpg-d4mbp86uk2gs738s5bg0-a.virginia-postgres.render.com
# db   = /mini_project_2_z393
# user = mini_project_2_z393_user

# %%
import pandas as pd

pd.read_sql_query("SELECT current_database() AS db, current_user AS user, version();", conn)
# Out:
# /tmp/ipykernel_492/3585097572.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT current_database() AS db, current_user AS user, version();", conn)
#                     db                      user  \
# 0  mini_project_2_z393  mini_project_2_z393_user
#
#                                              version
# 0  PostgreSQL 18.1 (Debian 18.1-1.pgdg12+2) on x8...

# %%
pd.read_sql_query("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema='public'
ORDER BY table_name;
""", conn)
# Out:
# /tmp/ipykernel_492/3524339476.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#         table_name
# 0          country
# 1         customer
# 2      orderdetail
# 3          product
# 4  productcategory
# 5         raw_data
# 6           region

# %%
pd.read_sql_query("SELECT * FROM raw_data LIMIT 5;", conn)
# Out:
# /tmp/ipykernel_492/717130449.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM raw_data LIMIT 5;", conn)
#                 name                        address         city  country  \
# 0   Alejandra Camino                    Gran Via, 1       Madrid    Spain
# 1    Alexander Feuer                    Heerstr. 22      Leipzig  Germany
# 2       Ana Trujillo  Avda. de la Constitucion 2222  Mexico D.F.   Mexico
# 3  Anabela Domingues        Av. Ines de Castro, 414    Sao Paulo   Brazil
# 4      Andre Fonseca                Av. Brasil, 442     Campinas   Brazil
#
#             region                                        productname  \
# 0  Southern Europe  Teatime Chocolate Biscuits;Guarana Fantastica;...
# 1   Western Europe  Rossle Sauerkraut;Tarte au sucre;Raclette Cour...
# ...

# %%
pd.read_sql_query("""
SELECT table_schema, table_name
FROM information_schema.tables
WHERE table_schema NOT IN ('pg_catalog','information_schema')
ORDER BY table_schema, table_name;
""", conn)
# Out:
# /tmp/ipykernel_492/2529550469.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#   table_schema       table_name
# 0       public          country
# 1       public         customer
# 2       public      orderdetail
# 3       public          product
# 4       public  productcategory
# 5       public         raw_data
# 6       public           region

# %%
pd.read_sql_query("SELECT * FROM raw_data LIMIT 10;", conn)
# Out:
# /tmp/ipykernel_492/1289761750.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM raw_data LIMIT 10;", conn)
#                  name                        address         city  country  \
# 0    Alejandra Camino                    Gran Via, 1       Madrid    Spain
# 1     Alexander Feuer                    Heerstr. 22      Leipzig  Germany
# 2        Ana Trujillo  Avda. de la Constitucion 2222  Mexico D.F.   Mexico
# 3   Anabela Domingues        Av. Ines de Castro, 414    Sao Paulo   Brazil
# 4       Andre Fonseca                Av. Brasil, 442     Campinas   Brazil
# 5           Ann Devon                 35 King George       London       UK
# 6      Annette Roulet          1 rue Alsace-Lorraine     Toulouse   France
# 7      Antonio Moreno                Mataderos  2312  Mexico D.F.   Mexico
# ...

# %%
q = """
SELECT
  relname AS table_name,
  n_live_tup AS approx_rows
FROM pg_stat_user_tables
ORDER BY approx_rows DESC;
"""
df = pd.read_sql_query(q, conn)   # assumes you already made conn successfully
df
# Out:
# /tmp/ipykernel_492/1631637335.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(q, conn)   # assumes you already made conn successfully
#         table_name  approx_rows
# 0         raw_data           91
# 1         customer            0
# 2          product            0
# 3  productcategory            0
# 4      orderdetail            0
# 5          country            0
# 6           region            0

# %%
tables = ["raw_data","region","country","customer","productcategory","product","orderdetail"]
for t in tables:
    df = pd.read_sql_query(f'SELECT COUNT(*) AS cnt FROM "{t}";', conn)
    print(t, int(df["cnt"].iloc[0]))
# Out:
# /tmp/ipykernel_341/1394829314.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(f'SELECT COUNT(*) AS cnt FROM "{t}";', conn)
# raw_data 91
# region 9
# country 21
# customer 91
# productcategory 8
# product 77
# orderdetail 609107

# %%
pd.read_sql_query("SELECT version();", conn)
# Out:
# /tmp/ipykernel_341/656059611.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT version();", conn)
#                                              version
# 0  PostgreSQL 18.1 (Debian 18.1-1.pgdg12+2) on x8...

# %%
pd.read_sql_query("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema='public'
ORDER BY table_name;
""", conn)
# Out:
# /tmp/ipykernel_341/3524339476.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("""
#         table_name
# 0          country
# 1         customer
# 2      orderdetail
# 3          product
# 4  productcategory
# 5         raw_data
# 6           region

# %%
tables = ["raw_data","region","country","customer","productcategory","product","orderdetail"]
for t in tables:
    df = pd.read_sql_query(f'SELECT COUNT(*) AS cnt FROM "{t}";', conn)
    print(t, int(df["cnt"].iloc[0]))
# Out:
# /tmp/ipykernel_341/1394829314.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(f'SELECT COUNT(*) AS cnt FROM "{t}";', conn)
# raw_data 91
# region 9
# country 21
# customer 91
# productcategory 8
# product 77
# orderdetail 609107

# %%
q = """
SELECT 'raw_data' AS table, COUNT(*) AS rows FROM raw_data
UNION ALL SELECT 'region', COUNT(*) FROM region
UNION ALL SELECT 'country', COUNT(*) FROM country
UNION ALL SELECT 'customer', COUNT(*) FROM customer
UNION ALL SELECT 'productcategory', COUNT(*) FROM productcategory
UNION ALL SELECT 'product', COUNT(*) FROM product
UNION ALL SELECT 'orderdetail', COUNT(*) FROM orderdetail
ORDER BY rows DESC;
"""
df = pd.read_sql_query(q, conn)
df
# Out:
# /tmp/ipykernel_341/3536820351.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(q, conn)
#              table    rows
# 0      orderdetail  609107
# 1         customer      91
# 2         raw_data      91
# 3          product      77
# 4          country      21
# 5           region       9
# 6  productcategory       8

# %%
q = "SELECT * FROM raw_data LIMIT 10;"
pd.read_sql_query(q, conn)
# Out:
# /tmp/ipykernel_341/3290224241.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(q, conn)
#                  name                        address         city  country  \
# 0    Alejandra Camino                    Gran Via, 1       Madrid    Spain
# 1     Alexander Feuer                    Heerstr. 22      Leipzig  Germany
# 2        Ana Trujillo  Avda. de la Constitucion 2222  Mexico D.F.   Mexico
# 3   Anabela Domingues        Av. Ines de Castro, 414    Sao Paulo   Brazil
# 4       Andre Fonseca                Av. Brasil, 442     Campinas   Brazil
# 5           Ann Devon                 35 King George       London       UK
# 6      Annette Roulet          1 rue Alsace-Lorraine     Toulouse   France
# 7      Antonio Moreno                Mataderos  2312  Mexico D.F.   Mexico
# ...
